# %%
# upto 500000 :- no tax
# 500000-750000 :- 10%
# 750000-1000000 :- 20%
# more than 1000000 :- 30%
inc = int(input("Enter the amount in integer:-"))
if inc<500000:
    print("No Tax")
elif inc>=500000 and inc<750000:
    tax1=(inc-499999) * 0.1
    print("Tax to be paid :-",tax1)
elif inc>=750000 and inc<1000000:
    tax2=((inc-749999)* 0.2)+ 25000
    print("Tax to be paid :-",tax2)
elif inc>=1000000:
    tax3=((inc-999999)* 0.3)+ 50000 + 25000
    print("Tax to be paid :-",tax3)
# Out:
# Tax to be paid :- 1785000.3
